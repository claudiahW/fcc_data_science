# %%
# load necessary imports and packages

import pandas as pd

# %%
#read the csv file 
df_gdp = pd.read_csv('gdp.csv', encoding='latin1')  # or 'cp1252'
df_gdp.pivot(index="year", columns="country", values="gdppc")
# Out:
# country  Afghanistan     Albania      Algeria      Angola  Argentina  \
# year
# 1880       585.46509   522.00000    819.18604   533.66669   1731.500
# 1890       635.93024   598.00000    923.37207   567.33331   2152.000
# 1900       686.39532   685.00000   1027.55810   601.00000   2756.000
# 1910       736.86047   780.00000   1131.74410   628.69232   3822.000
# 1920       731.75677   861.31250   1201.21620   682.62964   3473.000
# 1930       702.83783   929.57141   1255.81080   747.81482   4080.000
# 1940       673.91895   965.28571   1310.40540   813.00000   4161.000
# 1950       645.00000  1001.00000   1365.00000  1052.00000   4987.000
# 1960       739.00000  1451.00000   2088.00000  1253.00000   5559.000
# 1970       709.00000  2004.00000   2249.00000  1768.00000   7302.000
# 1980       690.00000  2347.00000   3152.00000   961.00000   8206.000
# 1990       604.00000  4557.40820  10238.88400  4806.43020  10833.503
# ...

# %%
df_gdp
# Out:
#       unid wbid      country  year        SES       gdppc  yrseduc  popshare
# 0        4  AFG  Afghanistan  1970   3.474212   709.00000      NaN  0.003097
# 1        4  AFG  Afghanistan  1920  26.968016   731.75677      NaN  0.003245
# 2        4  AFG  Afghanistan  1990   1.269530   604.00000      NaN  0.002347
# 3        4  AFG  Afghanistan  1960  15.763076   739.00000      NaN  0.003039
# 4        4  AFG  Afghanistan  2000   2.061114   565.00000      NaN  0.003309
# ...    ...  ...          ...   ...        ...         ...      ...       ...
# 2081   716  ZWE     Zimbabwe  1940  52.746567   813.00000      NaN  0.001113
# 2082   716  ZWE     Zimbabwe  2010  27.091389  1388.97300      NaN  0.002074
# 2083   716  ZWE     Zimbabwe  1990  59.110970  2526.07230      NaN  0.002039
# 2084   716  ZWE     Zimbabwe  1900  54.722645   601.00000      NaN  0.000996
# 2085   716  ZWE     Zimbabwe  1960  53.811077   938.00000      NaN  0.001268
#
# [2086 rows x 8 columns]

# %% [markdown]
# # pivot_table()

# %%
# read the excel 

pd.read_excel(r"C:\Users\user\Downloads\supermarket_sales.xlsx")
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df_supermarket = pd.read_excel(r"C:\Users\user\Downloads\supermarket_sales.xlsx")
df_supermarket
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# make a pivot table and add an aggregate function 
df_supermarket.pivot_table(index="Gender",
                           values=["Quantity","Total"],
                           aggfunc="sum")  # sum of Total by gender
# Out:
#         Quantity       Total
# Gender
# Female      2869  167882.925
# Male        2641  155083.824

# %% [markdown]
# # making static and interactive pivot tables

# %%
# reading new csv file 

df_population_raw = pd.read_csv(r'C:\Users\user\Downloads\population_total.csv')

# %%
df_population_raw
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %% [markdown]
# # making a pivot table

# %%
# dropping null values 
df_population_raw.dropna(inplace=True)

# %%
# making a pivot table 
df_pivot = df_population_raw.pivot(index='year',
                        columns='country',
                        values='population')

# %%
df_pivot = df_pivot[['United States', 'Iran', 'Kenya','India', 'China']]

# %%
# showing the pivot table
df_pivot
# Out:
# country  United States        Iran       Kenya         India         China
# year
# 1955.0     171685336.0  19294127.0   6987658.0  4.098806e+08  6.122416e+08
# 1960.0     186720571.0  21906914.0   8120080.0  4.505477e+08  6.604081e+08
# 1965.0     199733676.0  24954873.0   9530173.0  4.991233e+08  7.242190e+08
# 1970.0     209513341.0  28513866.0  11301394.0  5.551898e+08  8.276014e+08
# 1975.0     219081251.0  32729772.0  13575907.0  6.231029e+08  9.262409e+08
# 1980.0     229476354.0  38650246.0  16417197.0  6.989528e+08  1.000089e+09
# 1985.0     240499825.0  47347186.0  19877083.0  7.843600e+08  1.075589e+09
# 1990.0     252120309.0  56366217.0  23724579.0  8.732778e+08  1.176884e+09
# 1995.0     265163745.0  61442664.0  27768296.0  9.639226e+08  1.240921e+09
# 2000.0     281710909.0  65623405.0  31964557.0  1.056576e+09  1.290551e+09
# 2005.0     294993511.0  69762347.0  36624895.0  1.147610e+09  1.330776e+09
# ...

# %% [markdown]
# # 2 Lineplot

# %%
df_pivot.plot(kind='line', xlabel='Year', ylabel='Population', title='Population(1955-2020)')
# Out:
# <Axes: title={'center': 'Population(1955-2020)'}, xlabel='Year', ylabel='Population'>

# %% [markdown]
# # 3. Barplot
#
# ## 3.1 Single Barplot

# %%
df_pivot.index
# Out:
# Index([1955.0, 1960.0, 1965.0, 1970.0, 1975.0, 1980.0, 1985.0, 1990.0, 1995.0,
#        2000.0, 2005.0, 2010.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0],
#       dtype='float64', name='year')

# %%
# selecting only one year 

df_pivot_2020 =df_pivot[df_pivot.index.isin([2020])]

# %%
# show new dataframe 
df_pivot_2020
# Out:
# country  United States        Iran       Kenya         India         China
# year
# 2020.0     331002651.0  83992949.0  53771296.0  1.380004e+09  1.439324e+09

# %%
# transpose dataframe from rows to columns and vice versa
df_pivot_2020 = df_pivot_2020.T

# %%
# making barplot 
df_pivot_2020.plot(kind='bar', color='orange',
                   xlabel='Year', ylabel='Population',
                   title='Population 2020')
# Out:
# <Axes: title={'center': 'Population 2020'}, xlabel='Year', ylabel='Population'>

# %% [markdown]
# ## 3.2 Barplot grouped by "n" variables

# %%
df_pivot
# Out:
# country  United States        Iran       Kenya         India         China
# year
# 1955.0     171685336.0  19294127.0   6987658.0  4.098806e+08  6.122416e+08
# 1960.0     186720571.0  21906914.0   8120080.0  4.505477e+08  6.604081e+08
# 1965.0     199733676.0  24954873.0   9530173.0  4.991233e+08  7.242190e+08
# 1970.0     209513341.0  28513866.0  11301394.0  5.551898e+08  8.276014e+08
# 1975.0     219081251.0  32729772.0  13575907.0  6.231029e+08  9.262409e+08
# 1980.0     229476354.0  38650246.0  16417197.0  6.989528e+08  1.000089e+09
# 1985.0     240499825.0  47347186.0  19877083.0  7.843600e+08  1.075589e+09
# 1990.0     252120309.0  56366217.0  23724579.0  8.732778e+08  1.176884e+09
# 1995.0     265163745.0  61442664.0  27768296.0  9.639226e+08  1.240921e+09
# 2000.0     281710909.0  65623405.0  31964557.0  1.056576e+09  1.290551e+09
# 2005.0     294993511.0  69762347.0  36624895.0  1.147610e+09  1.330776e+09
# ...

# %%
df_pivot_sample = df_pivot[df_pivot.index.isin([1980, 1990, 2000, 2010, 2020])]

# %%
df_pivot_sample.plot(kind='bar', xlabel='Year', ylabel='Population', title='Population growth over time')
# Out:
# <Axes: title={'center': 'Population growth over time'}, xlabel='Year', ylabel='Population'>

# %% [markdown]
# # Piechart

# %%
# changing column name 
df_pivot_2020.rename(columns={2020:'2020'}, inplace=True)

# %%
# making the plot 

df_pivot_2020.plot(kind='pie', y='2020', title='Population in 2020 (%)')
# Out:
# <Axes: title={'center': 'Population in 2020 (%)'}, ylabel='2020'>

# %% [markdown]
# # Boxplot

# %% [markdown]
# ## 5.1 Single Boxplot

# %%
df_pivot['Kenya'].plot(kind='box', color='green', ylabel='Population')
# Out:
# <Axes: ylabel='Population'>

# %% [markdown]
# # 5.3. Multiple Boxplots

# %%
df_pivot.plot(kind='box', color='green', ylabel='Population ')
# Out:
# <Axes: ylabel='Population '>

# %% [markdown]
# # Histogram with pandas

# %%
df_pivot= df_pivot[['Kenya', 'China']].plot(kind='hist')

# %% [markdown]
# # 7. Scatterplot

# %%
# selecting a sample of raw data 
df_sample = df_population_raw['country'].isin(['United States','Kenya', 'Brazil', 'China'])

# %%
type(df_sample)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # 2.Lineplot
